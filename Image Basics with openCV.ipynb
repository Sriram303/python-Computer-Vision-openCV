# %%
### Image Basics with OpenCV

#### Goals
#### Begin bulding an understaning of how to use opencv library
#### Specifically how to open images and draw on them
#### Directly interact with an image through callback

#### OpenCV(Open source Computer Vision)
#### libraby of programming functions mailnly aimed at real-time computer vision(Computer vision: Using a computer to analyse images and videos in the same way as human does) Created by Intel in 1999, written in C++

####  Intro to images-openCV basics- opening image files

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# most common open cv error
#if u give wrong path for the image
img = cv2.imread("C:/Users/vasukisriram/Downloads/test/00.png")
type(img)
# Out:
# numpy.ndarray

# %%
# If type of an image returns NoneType which means your image path is not correct
img1 = cv2.imread('../Data/1.jpg') # there is no image called 1.jpg
type(img1)
# Out:
# NoneType

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB channel order
# OPENCV --> BGR channel order
#change image to RGB order
fixed_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fixed_image)

# %%
## read image as grayscale
#default imshow takes darker values and shows them in blue lighter values in yellowish
img_gray = cv2.imread("C:/Users/vasukisriram/Downloads/test/00.png",cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
fixed_image.shape
# Out:
# (1300, 1950, 3)

# %%
# resizing the image
res_img = cv2.resize(fixed_image,(1000,1000))
plt.imshow(res_img)

# %%
## resize with particular ratio
w_ratio = 0.5
h_ratio = 0.5
n_img = cv2.resize(fixed_image,(0,0),fixed_image,w_ratio,h_ratio)
plt.imshow(n_img)

# %%
## flip along different axis
#axis 0 - vertical
plt.imshow(cv2.flip(n_img,0))

# %%
plt.imshow(cv2.flip(n_img,1))
# axis 1 - horizontal

# %%
plt.imshow(cv2.flip(n_img,-1))
# axis 1 - inverted horizontal

# %%
# waitkey window displaying image name as puppy
img = cv2.imread("C:/Users/vasukisriram/Downloads/test/00.png")
import cv2
cv2.imshow('Puppy',img)
cv2.waitKey()
# Out:
# -1

# %%
# saving as new image
# cv2.imwrite('flip.jpg',n_img)

# larger display size
fig = plt.figure(figsize=(10,8))
fig = plt.figure(figsize=(20,50))
ax = fig.add_subplot(111)
ax.imshow(n_img)

# %%
####  Drawing on Images Basic shapes-Text-Polygons

# create a blank image
blank_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(blank_img)

# %%
blank_img.shape
# Out:
# (512, 512, 3)

# %%
#draw rectangle on the blank image

# Syntax: cv2.rectangle(image, start_point, end_point, color, thickness)

# Parameters:
# image: It is the image on which rectangle is to be drawn.
# start_point: It is the starting coordinates of rectangle. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).
# end_point: It is the ending coordinates of rectangle. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).
# color: It is the color of border line of rectangle to be drawn. For BGR, we pass a tuple. eg: (255, 0, 0) for blue color.
# thickness: It is the thickness of the rectangle border line in px. Thickness of -1 px will fill the rectangle shape by the specified color.

# Return Value: It returns an image.
#pt1 - top left corner
#pt2 - bottom right corner
cv2.rectangle(blank_img,pt1 =(200,200),pt2=(300,300),thickness=10,color=(255,0,0))

plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img,(384,0),(510,128),color = (0,255,0),thickness = 5)
cv2.rectangle(blank_img,(200,0),(0,200),(255,0,0),5)
cv2.rectangle(blank_img,(100,500),(0,400),(0,0,255),5)
plt.imshow(blank_img)

# %%
# Syntax: cv2.circle(image, center_coordinates, radius, color, thickness)

# Parameters: 
# image: It is the image on which circle is to be drawn. 
# center_coordinates: It is the center coordinates of circle. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value). 
# radius: It is the radius of circle. 
# color: It is the color of border line of circle to be drawn. For BGR, we pass a tuple. eg: (255, 0, 0) for blue color. 
# thickness: It is the thickness of the circle border line in px. Thickness of -1 px will fill the circle shape by the specified color.
# Return Value: It returns an image.

# draw circles
cv2.circle(blank_img,center=(256,256),radius=50,color=(0,255,0),thickness=5)

plt.imshow(blank_img)

# %%
## to draw filled in circles are images give thickness as negative 1(-1)
cv2.circle(blank_img,center=(400,400),radius=50,color=(0,255,0),thickness=-1)
plt.imshow(blank_img)

# %%
# Syntax: cv2.line(image, start_point, end_point, color, thickness)

# Parameters:
# image: It is the image on which line is to be drawn.
# start_point: It is the starting coordinates of line. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).
# end_point: It is the ending coordinates of line. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).
# color: It is the color of line to be drawn. For BGR, we pass a tuple. eg: (255, 0, 0) for blue color.
# thickness: It is the thickness of the line in px.

# Return Value: It returns an image.

# to draw line
cv2.line(blank_img,pt1=(0,0),pt2=(512,512),color=(0,0,255),thickness=3)
plt.imshow(blank_img)

# %%
# Syntax: cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])

# Parameters:
# image: It is the image on which text is to be drawn.
# text: Text string to be drawn.
# org: It is the coordinates of the bottom-left corner of the text string in the image. The coordinates are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).
# font: It denotes the font type. Some of font types are FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN, , etc.
# fontScale: Font scale factor that is multiplied by the font-specific base size.
# color: It is the color of text string to be drawn. For BGR, we pass a tuple. eg: (255, 0, 0) for blue color.
# thickness: It is the thickness of the line in px.
# lineType: This is an optional parameter.It gives the type of the line to be used.
# bottomLeftOrigin: This is an optional parameter. When it is true, the image data origin is at the bottom-left corner. Otherwise, it is at the top-left corner.

# Return Value: It returns an image.
    
# add text to image
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img,text='Arey!!!',org=(10,400),fontFace = font,
            fontScale=4,color=(255,255,255),thickness = 3,\
            lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %%
## custom polygons
new_bl_img = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(new_bl_img)

# %%
vertices = np.array([[100,300],[200,200],[400,100],[300,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 100],
#        [300, 400]])

# %%
# cv2 needs a 3 dimension whereas our vertices are in 2 D
pts = vertices.reshape((-1,1,2))
pts.shape
# Out:
# (4, 1, 2)

# %%
# Syntax: cv2.polylines(image, [pts], isClosed, color, thickness)

# Parameters:
# image: It is the image on which circle is to be drawn.
# pts: Array of polygonal curves.
# npts: Array of polygon vertex counters.
# ncontours: Number of curves.
# isClosed: Flag indicating whether the drawn polylines are closed or not. If they are closed, the function draws a line from the last vertex of each curve to its first
# vertex.
# color: It is the color of polyline to be drawn. For BGR, we pass a tuple.
# thickness: It is thickness of the polyline edges.
    
cv2.polylines(new_bl_img,[pts],isClosed= True,color=(255,255,255),thickness=10)
plt.imshow(new_bl_img)

# %%
blank_img1 = np.zeros((512,512,3),np.int32)
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],np.int32)
pts = vertices.reshape((-1,1,2))
pts
cv2.polylines(blank_img,[pts],True,(0,255,0),5)
plt.imshow(blank_img)

# %%
####  Drawing on Images with Mouse

import cv2
import numpy as np

###############
## FUNCTION ##
################

def draw_circle(event,x,y,flags,param):
    
    if event == cv2.EVENT_LBUTTONDOWN: #left mouse button click
        cv2.circle(img,(x,y),radius = 50,color=(0,255,0),thickness=5) #cv2.circle syntax

cv2.namedWindow(winname='My_drawing')
cv2.setMouseCallback('My_drawing',draw_circle)

##############################
## SHOWING IMAGE WITH OPENCV ##
########################

img = np.zeros((512,512,3),dtype=np.int8)
while True:
    cv2.imshow("My_drawing",img)
    
    if cv2.waitKey(20) & 0xFF == ord('q'): # press q to close the waitkey window
        break
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

###############
## FUNCTION ##
################

def draw_circle(event,x,y,flags,param):
    
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),radius = 50,color=(0,255,0),thickness=-1)
        
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),radius = 50,color=(255,0,0),thickness=-1)

cv2.namedWindow(winname='My_drawing')
cv2.setMouseCallback('My_drawing',draw_circle)

##############################
## SHOWING IMAGE WITH OPENCV ##
########################
img = np.zeros((512,512,3),dtype=np.int8)
while True:
    cv2.imshow("My_drawing",img)
    
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()

# %%
# DIRECT DRAWING CONTINUOUS

import numpy as np
import cv2

# variables

drawing = False
ix,iy = -1,-1

# Function
def draw_rect(event,x,y,flags,param):
    global ix,iy,drawing
    
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)

#section for shwoing the image
img = np.zeros((512,512,3),dtype=np.int8)

cv2.namedWindow(winname = 'my_drawing')
cv2.setMouseCallback('my_drawing',draw_rect)

while True:
    
    cv2.imshow('my_drawing',img)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()

# %%
### Image Basics Assessment
#### Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# TASK: Open the dog_backpack.jpg image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('C:/Users/vasukisriram/Downloads/Python OpenCV DL # DATA GH/Data/dog_backpack.jpg')
plt.imshow(img)

# %%
# Syntax: cv2.cvtColor(src, code[, dst[, dstCn]])

# Parameters:
# src: It is the image whose color space is to be changed.
# code: It is the color space conversion code.
# dst: It is the output image of the same size and depth as src image. It is an optional parameter.
# dstCn: It is the number of channels in the destination image. If the parameter is 0 then the number of the channels is derived automatically from src and code. It is an optional parameter.

# Return Value: It returns an image.
    
fixed_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %%
# TASK: Flip the image upside down and display it in the notebook
plt.imshow(cv2.flip(fixed_img,0))

# TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.
plt.imshow(cv2.rectangle(fixed_img,pt1=(200,380),pt2=(600,700),color=(255,0,0),thickness=10))

# TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation
vertices = np.array([[250,700],[400,400],[600,700]],dtype = np.int32)
pts = np.reshape(vertices,(-1,1,2))
pts.shape
# Out:
# (3, 1, 2)

# %%
o_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# Syntax: cv2.polylines(image, [pts], isClosed, color, thickness)

# Parameters:
# image: It is the image on which circle is to be drawn.
# pts: Array of polygonal curves.
# npts: Array of polygon vertex counters.
# ncontours: Number of curves.
# isClosed: Flag indicating whether the drawn polylines are closed or not. If they are closed, the function draws a line from the last vertex of each curve to its first
# vertex.
# color: It is the color of polyline to be drawn. For BGR, we pass a tuple.
# thickness: It is thickness of the polyline edges.
    
plt.imshow(cv2.polylines(o_img,[pts],isClosed=True,color=(0,0,255),thickness = 10))

# %%
#  Can you figure our how to fill in this triangle? It requires a different function 
# SYNTAX cv2.fillPoly(img, pts, color[, lineType[, shift[, offset]]]) → None
o_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(cv2.fillPoly(o_img,[pts],color=(0,0,255)))

# %%
# TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). 
# Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.
import numpy as np
import cv2

def draw_circle(event,x,y,flags,param):
    
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,0,255),5)

cv2.namedWindow(winname='task')
cv2.setMouseCallback('task',draw_circle)
while True:
    cv2.imshow('task',img)
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()
