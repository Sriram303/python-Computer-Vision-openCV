# %%
### plot and display images

import numpy as np

import matplotlib.pyplot as plt
# funtion to open up images
# PIL - Python image library
# choose image format as jpeg,jpg,png...to upload
from PIL import Image
pic = Image.open("C:/Users/vasukisriram/Downloads/test/00.png")
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1950x1300 at 0x828FB3BB88>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
# converting pic to an array
pic_arr = np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
# get shape after converting to numpy array
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
#plot the second channel 
# Pic_arr x,y axis 0-red ,1-blue, 2-green
plt.imshow(pic_arr[:,:,1],cmap='gray')

# %%
plt.imshow(pic_arr[:,:,2],cmap='gray')

# %%
# R G B 
#MATPLOT LIB ---> RGB
#OPEMCV --->BGR
pic_arr[:,:,0]
# Out:
# array([[95, 97, 98, ..., 25, 25, 25],
#        [95, 96, 96, ..., 25, 25, 25],
#        [95, 94, 94, ..., 25, 25, 25],
#        ...,
#        [19, 20, 20, ..., 23, 24, 24],
#        [20, 20, 19, ..., 23, 24, 24],
#        [20, 19, 19, ..., 23, 24, 24]], dtype=uint8)

# %%
plt.imshow(pic_arr)

# %%
# Red for Pic_arr
plt.imshow(pic_arr[:,:,0])

# %%
# Blue for Pic_arr
plt.imshow(pic_arr[:,:,1])

# %%
# Green for Pic_arr
plt.imshow(pic_arr[:,:,2])

# %%
pic_rgb = pic_arr.copy()
plt.imshow(pic_rgb)

# %%
pic_rgb[:,:,0] = 0 
# red is washed out,mixture of green and blue
plt.imshow(pic_rgb)

# %%
pic_rgb[:,:,1] = 0
# R & G washed out,only blue
plt.imshow(pic_rgb)

# %%
# in previous pics red is washed out first then green then last is blue
# create your own wash out sequence accordingly
pic_rgb[:,:,2] = 0
plt.imshow(pic_rgb)

# %%
# NumPy and Image Assessment
# COMPLETE THE TASKS IN BOLD BELOW.
# TASK: Import NumPy
import numpy as np

# %%
# TASK: Create a 5 by 5 array where every number is a 10
a = (np.zeros(25) + 10)
a
# Out:
# array([10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.,
#        10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10., 10.])

# %%
a.reshape((5,5))
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
# TASK: Run the cell below to create an array of random numbers and see if you can figure out how it works.
# This line sets a "seed" so you get the same random numbers we do
np.random.seed(101)
# This line creates an array of random numbers
arr = np.random.randint(low=0,high=100,size=(5,5))
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
# TASK: What are the largest and smalled values in this array?
arr.max()
# Out:
# 95

# %%
arr.min()
# Out:
# 4

# %%
# TASK: Use PIL and matplotlib to read and display the ../DATA/00-puppy.jpg image
import matplotlib.pyplot as plt

# %%
# funtion to open up images
# PIL - Python image library
# choose image format as jpeg,jpg,png...to upload
from PIL import Image
pic1 = Image.open("C:/Users/vasukisriram/Downloads/test/p.jpeg")
pic1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1242x710 at 0x8295C7B408>

# %%
# TASK: Convert the image to a NumPy Array
pic_arr = np.asarray(pic1)
pic_arr.shape
# Out:
# (710, 1242, 3)

# %%
# FINAL TASK: Use slicing to set the RED and GREEN channels of the picture to 0, then use imshow() to show the isolated blue channel
pic_cp = pic_arr.copy()
pic_cp.shape
# Out:
# (710, 1242, 3)

# %%
pic_cp[:,:,0] = 0

# %%
pic_cp[:,:,1] = 0

# %%
print(pic_cp.shape)
# Out:
# (710, 1242, 3)

# %%
plt.imshow(pic_cp)

# %%
#plot the second channel 
# Pic_arr x,y axis 0-red ,1-blue, 2-green
#cmap - viridis, plasma, inferno, magma for color blind people
plt.imshow(pic_arr[:,:,1],cmap='magma')

# %%
plt.imshow(pic_arr[:,:,1],cmap='viridis')
